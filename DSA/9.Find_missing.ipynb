# %% [markdown]
# # Find missing number

# %% [markdown]
# Given an integer array of size n containing distinct values in the range from 0 to n (inclusive), return the only number missing from the array within this range.

# %%
# Approach 1- sum of numbers n(n+1)/2

def missing_num1(nums):
    n=len(nums)
    num_sum=n * (n+1)//2

    actual_sum=0

    for i in range(n):
        actual_sum=actual_sum+ nums[i]
    
    return num_sum-actual_sum
    

print(missing_num1([0,2,3,4,1]))
# Out:
# 5
